# %%
import os
import numpy as np
from cmdstanpy import Model, StanFit

# %%
with open('worldcup_2014.data.json', 'r') as fd:
    data_dict = json.load(fd)
data_dict.keys()
# Out:
# dict_keys(['I', 'N', 'team_1', 'team_2', 'score_1', 'score_2', 'prior_score'])

# %%
stan_wc = Model(stan_file='worldcup_rep_ag.stan')
stan_wc.compile()
stan_wc
# Out:
# INFO:cmdstanpy:compiling c++
# INFO:cmdstanpy:compiled model file: /Users/nitya/NYCPyLadies_CmdStanPy/data/worldcup_gelman/worldcup_rep_ag
# Model(name=worldcup_rep_ag,  stan_file="worldcup_rep_ag.stan", exe_file="/Users/nitya/NYCPyLadies_CmdStanPy/data/worldcup_gelman/worldcup_rep_ag")

# %%
worldcup_fit = stan_wc.sample(data=data_dict, chains=4)
# Out:
# INFO:cmdstanpy:start chain 1
# INFO:cmdstanpy:start chain 2
# INFO:cmdstanpy:finish chain 2
# INFO:cmdstanpy:finish chain 1
# INFO:cmdstanpy:start chain 3
# INFO:cmdstanpy:start chain 4
# INFO:cmdstanpy:finish chain 3
# INFO:cmdstanpy:finish chain 4

# %%
worldcup_fit.diagnose()
# Out:
# WARNING:cmdstanpy:Processing csv files: /var/folders/p4/76cck04j075g95k8wbfvw1ch0000gn/T/tmp2oa71iv0/stan-worldcup_rep_ag-draws-1-ixlgtoqw.csv, /var/folders/p4/76cck04j075g95k8wbfvw1ch0000gn/T/tmp2oa71iv0/stan-worldcup_rep_ag-draws-2-ur64n3o4.csv, /var/folders/p4/76cck04j075g95k8wbfvw1ch0000gn/T/tmp2oa71iv0/stan-worldcup_rep_ag-draws-3-fwpsnk8j.csv, /var/folders/p4/76cck04j075g95k8wbfvw1ch0000gn/T/tmp2oa71iv0/stan-worldcup_rep_ag-draws-4-5f2ol9pz.csv
#
# Checking sampler transitions treedepth.
# Treedepth satisfactory for all transitions.
#
# Checking sampler transitions for divergences.
# No divergent transitions found.
#
# Checking E-BFMI - sampler transitions HMC potential energy.
# E-BFMI satisfactory for all transitions.
#
# Effective sample size satisfactory.
#
# Split R-hat values satisfactory all parameters.
#
# Processing complete, no problems detected.
# 'Processing csv files: /var/folders/p4/76cck04j075g95k8wbfvw1ch0000gn/T/tmp2oa71iv0/stan-worldcup_rep_ag-draws-1-ixlgtoqw.csv, /var/folders/p4/76cck04j075g95k8wbfvw1ch0000gn/T/tmp2oa71iv0/stan-worldcup_rep_ag-draws-2-ur64n3o4.csv, /var/folders/p4/76cck04j075g95k8wbfvw1ch0000gn/T/tmp2oa71iv0/stan-worldcup_rep_ag-draws-3-fwpsnk8j.csv, /var/folders/p4/76cck04j075g95k8wbfvw1ch0000gn/T/tmp2oa71iv0/stan-worldcup_rep_ag-draws-4-5f2ol9pz.csv\n\nChecking sampler transitions treedepth.\nTreedepth satisfactory for all transitions.\n\nChecking sampler transitions for divergences.\nNo divergent transitions found.\n\nChecking E-BFMI - sampler transitions HMC potential energy.\nE-BFMI satisfactory for all transitions.\n\nEffective sample size satisfactory.\n\nSplit R-hat values satisfactory all parameters.\n\nProcessing complete, no problems detected.'

# %%
worldcup_fit.summary()
# Out:
#                 Mean      MCSE    StdDev         5%        50%        95%  \
# name
# lp__      -73.798100  0.213522  5.862020 -83.553100 -73.724200 -64.232700
# beta        1.202200  0.004829  0.291102   0.720863   1.207480   1.671170
# alpha[1]   -0.349170  0.011944  0.876875  -1.745970  -0.365585   1.117090
# alpha[2]   -0.134345  0.011826  0.843854  -1.540640  -0.123128   1.245920
# alpha[3]    0.568092  0.013711  0.906707  -0.958332   0.593291   1.995390
# alpha[4]   -0.472430  0.014748  0.986141  -2.056530  -0.489225   1.181970
# alpha[5]    0.039381  0.010945  0.884362  -1.385810   0.055567   1.504620
# alpha[6]    0.385443  0.012219  0.881594  -1.063840   0.395494   1.842030
# alpha[7]    0.606241  0.014090  0.900097  -0.863305   0.635618   2.070390
# alpha[8]   -0.349644  0.012285  0.915085  -1.831640  -0.380505   1.193010
# alpha[9]   -0.520607  0.012968  0.912591  -1.978810  -0.555003   1.030050
# alpha[10]   0.043057  0.011228  0.850871  -1.370080   0.033486   1.431630
# alpha[11]   0.801367  0.015055  0.945228  -0.815969   0.845621   2.288760
# alpha[12]  -0.167581  0.012166  0.930262  -1.693560  -0.177036   1.384630
# alpha[13]  -0.123227  0.011522  0.923362  -1.644310  -0.126195   1.407950
# alpha[14]  -0.288866  0.012050  0.922878  -1.814200  -0.274431   1.196890
# y_rep[60]   0.426677  0.027340  1.677400  -2.373700   0.460010   3.085570
# y_rep[61]  -0.282808  0.026156  1.658330  -2.976780  -0.291483   2.377000
# y_rep[62]  -0.159771  0.027294  1.652900  -2.781210  -0.190422   2.501020
# y_rep[63]   0.161317  0.028046  1.705360  -2.602760   0.164622   2.884280
# y_rep[64]   0.247614  0.025395  1.616340  -2.349470   0.238950   2.826890
#
#               N_Eff  N_Eff/s     R_hat
# name
# lp__        753.716   503.63  1.003610
# beta       3633.220  2427.70  0.999339
# alpha[1]   5389.650  3601.35  0.999489
# alpha[2]   5091.370  3402.03  1.000340
# alpha[3]   4373.100  2922.08  0.999135
# alpha[4]   4470.940  2987.46  0.999644
# alpha[5]   6528.540  4362.34  0.999972
# alpha[6]   5205.810  3478.50  0.999763
# alpha[7]   4081.210  2727.05  1.000020
# alpha[8]   5548.010  3707.16  0.999601
# alpha[9]   4952.460  3309.21  0.999634
# alpha[10]  5742.390  3837.04  0.999382
# alpha[11]  3941.920  2633.98  0.999582
# alpha[12]  5846.630  3906.69  0.999585
# alpha[13]  6422.110  4291.23  1.000350
# alpha[14]  5865.190  3919.09  1.000010
# alpha[15]  6035.250  4032.73  0.999945
# alpha[16]  5840.530  3902.62  1.000190
# alpha[17]  5771.250  3856.32  0.999560
# alpha[18]  6369.170  4255.86  0.999837
# alpha[19]  5772.110  3856.90  0.999448
# alpha[20]  5593.440  3737.52  0.999336
# alpha[21]  6088.730  4068.46  0.999359
# alpha[22]  6599.320  4409.64  0.999891
# alpha[23]  6525.380  4360.23  0.999858
# alpha[24]  5317.480  3553.12  0.999439
# alpha[25]  6160.120  4116.17  0.999633
# alpha[26]  3283.500  2194.02  1.001680
# alpha[27]  6113.150  4084.78  0.999308
# alpha[28]  4357.310  2911.54  0.999594
# ...             ...      ...       ...
# y_rep[35]  4058.660  2711.98  1.000160
# y_rep[36]  4052.880  2708.12  0.999762
# y_rep[37]  4010.470  2679.78  0.999740
# y_rep[38]  4077.450  2724.53  0.999732
# y_rep[39]  3654.810  2442.13  1.000720
# y_rep[40]  3774.450  2522.07  0.999384
# y_rep[41]  4141.760  2767.51  1.001270
# y_rep[42]  4196.660  2804.19  0.999915
# y_rep[43]  3954.580  2642.43  1.000950
# y_rep[44]  4208.030  2811.79  0.999699
# y_rep[45]  3924.860  2622.58  0.999677
# y_rep[46]  4165.450  2783.34  0.999669
# y_rep[47]  4265.840  2850.42  1.000170
# y_rep[48]  3404.730  2275.02  1.000390
# y_rep[49]  4107.090  2744.34  0.999776
# y_rep[50]  3932.140  2627.44  1.000790
# y_rep[51]  3831.650  2560.29  1.000620
# y_rep[52]  3341.600  2232.84  1.000140
# y_rep[53]  4185.140  2796.49  1.000250
# y_rep[54]  4130.210  2759.79  0.999241
# y_rep[55]  3981.710  2660.56  1.000910
# y_rep[56]  4105.410  2743.22  0.999914
# y_rep[57]  3718.990  2485.02  0.999552
# y_rep[58]  3871.870  2587.17  1.000730
# y_rep[59]  4031.270  2693.68  1.000450
# y_rep[60]  3764.340  2515.31  1.001870
# y_rep[61]  4019.920  2686.09  1.000120
# y_rep[62]  3667.360  2450.51  0.999811
# y_rep[63]  3697.310  2470.53  0.999979
# y_rep[64]  4051.050  2706.90  1.000470
#
# [132 rows x 9 columns]
